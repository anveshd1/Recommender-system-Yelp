# %%
#Importing libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
#importing datasets
business = pd.read_csv("../business.csv")
checkin = pd.read_csv("../checkin.csv")
photos = pd.read_csv("../photos.csv")
review = pd.read_csv("../review.csv")
tip = pd.read_csv("../tip.csv")
user = pd.read_csv("../user.csv")

# %%
business.head()
# Out:
#   attributes.Ambience.divey attributes.RestaurantsDelivery attributes.DogsAllowed postal_code hours.Thursday attributes.HairSpecializesIn.coloring attributes.BestNights.sunday attributes.BYOB attributes.AgesAllowed attributes.Music.video hours.Friday   latitude attributes.Alcohol attributes.Ambience.classy attributes.RestaurantsTableService             business_id attributes.Ambience.touristy attributes.RestaurantsCounterService attributes.Corkage attributes.RestaurantsGoodForGroups                                                  categories                                name attributes.BusinessAcceptsBitcoin attributes.HappyHour attributes.WheelchairAccessible attributes.Ambience.hipster attributes.BusinessAcceptsCreditCards  is_open attributes.DietaryRestrictions.vegetarian attributes.Music.live attributes.Music.background_music neighborhood attributes.BusinessParking.lot attributes.Music.karaoke  review_count attributes.GoodForMeal.breakfast attributes.NoiseLevel attributes.HairS
# ...

# %%
business['city'].value_counts().head(10)
# Out:
# Las Vegas     24768
# Phoenix       15656
# Toronto       15483
# Charlotte      7557
# Scottsdale     7510
# Pittsburgh     5688
# Montréal       5175
# Mesa           5146
# Henderson      4130
# Tempe          3949
# Name: city, dtype: int64

# %%
#filter for Charlotte
business_clt = business[business['city'] == 'Charlotte']

# %%
review.head()
# Out:
#    funny                 user_id               review_id  \
# 0      0  cjpdDjZyprfyDG3RlkVG3w  VfBHSwC5Vz_pbFluy07i9Q
# 1      0  bjTcT8Ty4cJZhEOEo01FGA  3zRpneRKDsOPq92tq7ybAA
# 2      0  AXgRULmWcME7J6Ix3I--ww  ne5WhI1jUFOcRn-b-gAzHA
# 3      0  oU2SSOmsp_A8JYI7Z2JJ5w  llmdwOgDReucVoWEry61Lw
# 4      0  0xtbPEna2Kei11vsU-U2Mw  DuffS87NaSMDmIfluvT83g
#
#                                                 text             business_id  \
# 0  My girlfriend and I stayed here for 3 nights a...  uYHaNptLzDLoV_JZ_MuzUA
# 1  If you need an inexpensive place to stay for a...  uYHaNptLzDLoV_JZ_MuzUA
# 2  Mittlerweile gibt es in Edinburgh zwei Ableger...  uYHaNptLzDLoV_JZ_MuzUA
# 3  Location is everything and this hotel has it! ...  uYHaNptLzDLoV_JZ_MuzUA
# 4  gute lage im stadtzentrum. shoppingmeile und s...  uYHaNptLzDLoV_JZ_MuzUA
#
#    stars        date  useful  cool
# 0      5  2016-07-12       0     0
# 1      3  2016-10-02       0     0
# 2      3  2015-09-17       0     0
# ...

# %%
filter_clt = list(business_clt['business_id'])

# %%
#Extracting reviews for Charlotte 
review_clt = review[review['business_id'].isin(filter_clt)]

# %%
review_clt.shape
# Out:
# (212345, 9)

# %%
counts = review_clt['user_id'].value_counts()

# %%
#selecting reviews from users who gave atleast 25 reviews 
review_clt1 = review_clt[review_clt['business_id'].isin(counts2[counts2 > 25].index)]

# %%
#selecting restaurants with alteast 150 reviews
review_clt2 = review_clt1[review_clt1['user_id'].isin(counts[counts > 150].index)]

# %%
review_clt2.shape
# Out:
# (18346, 9)

# %%
yelpclt = review_clt2[['date','user_id' , 'business_id' , 'stars' ]]

# %%
#Yelp user review data for Charlotte.This is the final data used for receommender models
yelpclt.to_csv("yelp_clt_b100_u50.csv")
